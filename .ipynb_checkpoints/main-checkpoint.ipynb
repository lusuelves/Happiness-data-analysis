# %%
import requests
import numpy as np
import pandas as pd
import re
happy_data = pd.read_csv('Happy2019.csv', engine = 'python')
happy_data
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#There are no null values and every column is useful for analysis
null_cols = happy_data.isnull().sum()
print("Number of columns with any null value: " , len(null_cols[null_cols > 0]))
# Out:
# Number of columns with any null value:  0

# %%
#I added a column with the code for each country to search the climate api
def country_code(country):
    try:
        country_data = requests.get(f"https://restcountries.eu/rest/v2/name/{country}?fullText=true").json()
        return[country['alpha3Code'] for country in country_data][0]
    except:
        return None
countries = happy_data['Country or region']
happy_data['Code'] = [country_code(country) for country in countries]
null_codes = happy_data[happy_data['Code'].isnull() == True]
null_codes['Country or region']
# Out:
# 14              United Kingdom
# 18               United States
# 38           Trinidad & Tobago
# 45                      Kosovo
# 53                 South Korea
# 60                     Bolivia
# 63             Northern Cyprus
# 67                      Russia
# 70                     Moldova
# 83             North Macedonia
# 93                     Vietnam
# 102        Congo (Brazzaville)
# 107                  Venezuela
# 109    Palestinian Territories
# 116                       Iran
# 126           Congo (Kinshasa)
# 148                      Syria
# 152                   Tanzania
# Name: Country or region, dtype: object

# %%
#I changed the code null values to the real ones, the API could not find
real_code = ["GBR","USA", "TTO", "RKS", "KOR", "BOL", "CYP", "RUS", "MDA", "MKD", "VNM","COD","VEN","PSE","IRN","COD","SYR","TZA"]
countries = null_codes['Country or region'].tolist()
correction = zip(countries,real_code)
def replace_code():
    for (country, code) in correction:
        happy_data.loc[happy_data['Country or region'] == country, 'Code'] = code
    return happy_data.head()
replace_code()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption Code
# 0                      0.393  FIN
# 1                      0.410  DNK
# ...

# %%
#New column with average anual temperature 2012 (could not find data for 2019)
def temperature(code):
    try:
        temp_resp =  requests.get(f"http://climatedataapi.worldbank.org/climateweb/rest/v1/country/cru/tas/year/{code}.json").json()
        return [temp['data'] for temp in temp_resp if temp['year'] == 2012][0]
    except: 
        return None
codes = happy_data['Code'].tolist()
temperatures = [temperature(code) for code in codes]
temperatures
# Out:
# [1.5238693,
#  8.385157,
#  1.0650705,
#  2.697072,
#  10.226961,
#  6.918981,
#  1.9937834,
#  10.483627,
#  -5.7146006,
#  7.7780952,
#  21.534817,
#  24.999702,
#  21.021591,
#  10.016666,
#  8.891592,
#  9.406421,
#  9.452757,
#  10.370833,
#  7.939524,
#  8.855952,
#  28.020578,
#  None,
#  21.962017,
#  11.454212,
#  20.666668,
#  8.095709,
#  24.315754,
#  25.754114,
#  28.408335,
#  14.733118,
#  25.559324,
#  25.582172,
#  18.669117,
#  None,
#  24.641071,
#  13.4415,
#  28.8,
#  9.288446,
#  26.478333,
#  8.488121,
#  12.314749,
#  6.8023615,
#  25.143543,
#  10.281019,
#  25.008701,
#  None,
#  14.542911,
#  10.799427,
#  19.669445,
#  22.373943,
#  26.467361,
#  26.749786,
#  6.221244,
#  11.606349,
#  5.6226187,
#  25.436905,
#  24.704166,
#  11.769478,
#  24.561691,
#  6.2187185,
#  20.923494,
#  11.566256,
#  24.075481,
#  19.669445,
#  20.508705,
#  16.082819,
#  19.374298,
#  -4.7304997,
#  26.448437,
#  11.193683,
#  10.835257,
#  23.009312,
#  9.645139,
# ...

# %%
happy_data['Average Temperature'] = temperatures
happy_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption Code  Average Temperature
# 0                      0.393  FIN             1.523869
# ...

# %%
#Null values for average temperature, can we solve it?
happy_data[happy_data['Average Temperature'].isnull() == True]
# Out:
#      Overall rank    Country or region  Score  GDP per capita  Social support  \
# 21             22                Malta  6.726           1.300           1.520
# 33             34            Singapore  6.262           1.572           1.463
# 45             46               Kosovo  6.100           0.882           1.232
# 102           103  Congo (Brazzaville)  4.812           0.673           0.799
# 126           127     Congo (Kinshasa)  4.418           0.094           1.125
# 155           156          South Sudan  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 21                     0.999                         0.564       0.375
# 33                     1.141                         0.556       0.271
# 45                     0.758                         0.489       0.262
# 102                    0.508                         0.372       0.105
# ...

# %%
#New column with average anual precipitations 2012 (could not find data for 2019)
def precipitations(code):
    try:
        temp_resp =  requests.get(f"http://climatedataapi.worldbank.org/climateweb/rest/v1/country/cru/pr/year/{code}.json").json()
        return [temp['data'] for temp in temp_resp if temp['year'] == 2012][0]
    except: 
        return None
codes = happy_data['Code'].tolist()
precipitations = [precipitations(code) for code in codes]
precipitations
# Out:
# [54.050922,
#  59.465107,
#  85.08235,
#  77.211105,
#  70.2049,
#  127.70278,
#  64.040695,
#  135.48471,
#  39.09154,
#  97.199524,
#  41.83538,
#  194.90237,
#  28.588257,
#  89.15,
#  118.43199,
#  96.422134,
#  60.70291,
#  82.13307,
#  56.28993,
#  57.49,
#  3.905442,
#  None,
#  59.51433,
#  72.93797,
#  187.2738,
#  49.732033,
#  184.20326,
#  5.8779325,
#  3.098611,
#  44.533546,
#  191.10336,
#  139.9481,
#  113.390526,
#  None,
#  132.23929,
#  70.85733,
#  3.6833332,
#  52.230114,
#  118.878334,
#  54.46579,
#  18.733522,
#  65.03792,
#  191.4333,
#  100.034256,
#  183.09154,
#  None,
#  52.003853,
#  49.469112,
#  63.375,
#  179.90529,
#  9.275,
#  147.42734,
#  67.8365,
#  143.3758,
#  70.15919,
#  163.93571,
#  95.27917,
#  150.7461,
#  179.64789,
#  20.922756,
#  88.16757,
#  46.342384,
#  95.0697,
#  63.375,
#  119.015564,
#  64.44897,
#  24.94371,
#  37.28559,
#  257.47986,
#  57.77352,
#  42.93312,
#  3.1468103,
#  90.16111,
#  41.881157,
#  80.39058,
# ...

# %%
happy_data['Average Precipitations'] = precipitations
happy_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption Code  Average Temperature  Average Precipitations
# ...

# %%
#Null values for average temperature, can we solve it?
happy_data[happy_data['Average Precipitations'].isnull() == True]
# Out:
#      Overall rank    Country or region  Score  GDP per capita  Social support  \
# 21             22                Malta  6.726           1.300           1.520
# 33             34            Singapore  6.262           1.572           1.463
# 45             46               Kosovo  6.100           0.882           1.232
# 102           103  Congo (Brazzaville)  4.812           0.673           0.799
# 126           127     Congo (Kinshasa)  4.418           0.094           1.125
# 155           156          South Sudan  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 21                     0.999                         0.564       0.375
# 33                     1.141                         0.556       0.271
# 45                     0.758                         0.489       0.262
# 102                    0.508                         0.372       0.105
# ...

# %%
from bs4 import BeautifulSoup
import requests

res = requests.get("https://en.wikipedia.org/wiki/List_of_countries_by_suicide_rate")
soup = BeautifulSoup(res.text,'html.parser')
table = soup.find_all('tbody')[3]
rows = table.find_all('tr')
def suicide_rate(row):
    try:
        info = row.find_all('td')
        return {
            'Country': info[1].select('a[href][title]')[0].text,
            'Continent': info[2].text.strip(),
            'Suicide per 1000': info[3].text.strip()
        }
    except:
        return None
suicides = [suicide_rate(row) for row in rows][2:]
suicides = pd.DataFrame(suicides)
suicides
# Out:
#                  Country      Continent Suicide per 1000
# 0                 Guyana  South America             30.2
# 1                Lesotho         Africa             28.9
# 2                 Russia         Europe             26.5
# 3              Lithuania         Europe             25.7
# 4               Suriname  South America             23.2
# ..                   ...            ...              ...
# 178              Jamaica  North America              2.0
# 179              Grenada  North America              1.7
# 180              Bahamas  North America              1.6
# 181  Antigua and Barbuda  North America              0.5
# 182             Barbados  North America              0.4
#
# [183 rows x 3 columns]

# %%
#Data scraping from wikipedia to extract suicide rate, new column to de dataframe
import pandas as pd
happy_data['Country or region'].tolist()
happy_data['Suicide per 1000'] = 0
happy_data['Continent'] = ''
def what(country):
    try: 
        suicide = suicides.loc[suicides['Country'] == country]['Suicide per 1000'].iloc[0]
        continent = suicides.loc[suicides['Country'] == country]['Continent'].iloc[0]
        happy_data.loc[happy_data['Country or region'] == country, 'Suicide per 1000'] = suicide
        happy_data.loc[happy_data['Country or region'] == country, 'Continent'] = continent
        return happy_data.loc[happy_data['Country or region'] == country]
    except:
        happy_data.loc[happy_data['Country or region'] == country, 'Suicide per 1000'] = None
        return None
suicides_rate = [what(country) for country in happy_data['Country or region'].tolist()]
happy_data
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#Null values for suicide rate
happy_data[happy_data['Suicide per 1000'].isnull() == True]
# Out:
#      Overall rank        Country or region  Score  GDP per capita  \
# 24             25                   Taiwan  6.446           1.368
# 38             39        Trinidad & Tobago  6.192           1.231
# 45             46                   Kosovo  6.100           0.882
# 63             64          Northern Cyprus  5.718           1.263
# 75             76                Hong Kong  5.430           1.438
# 102           103      Congo (Brazzaville)  4.812           0.673
# 109           110  Palestinian Territories  4.696           0.657
# 126           127         Congo (Kinshasa)  4.418           0.094
# 134           135                Swaziland  4.212           0.811
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 24            1.430                    0.914                         0.351
# 38            1.477                    0.713                         0.489
# 45            1.232                    0.758                         0.489
# ...

# %%
from selenium import webdriver

class PageGetter:
    driver = False
    def __init__(self, defaultBrowser='firefox'):
        if defaultBrowser == 'firefox':
            self.driver = webdriver.Firefox()
        elif defaultBrowser == 'chrome':
            self.driver = webdriver.Chrome("/Users/luciasuelves/Downloads/chromedriver") 
        else:
            raise Exception('Not a browser')

    def getPage(self, url):
        if not self.driver:
            raise Exception("You should start a browser connection")
        self.driver.get(url)
        html = self.driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        return soup

    def close(self):
        self.driver.quit()
        
pg = PageGetter("chrome")
hdr_data = pg.getPage("http://hdr.undp.org/en/data")
pg.close()
#hdr_data.find_all('tr')

# %%
hdr_data.find_all('table')
# Out:
# []

# %%
res = requests.get("http://hdr.undp.org/en/data").text
BeautifulSoup(res,"html.parser").find_all('tr')
# Out:
# []

# %%
avg_happy = happy_data.groupby('Continent', as_index = False).agg({'Overall rank':'mean'})
avg_happy.columns = ['Continent', 'Avg continent happiness']
happy_data = pd.merge(happy_data, avg_happy, on="Continent")

happy_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption Code  Average Temperature  \
# ...

# %%
happy_data["Suicide per 1000"] = pd.to_numeric(happy_data['Suicide per 1000'])
avg_suicide = happy_data.groupby('Continent', as_index = False).agg({'Suicide per 1000':'mean'})
avg_suicide.columns = ['Continent', 'Avg continent suicide']
happy_data = pd.merge(happy_data, avg_suicide, on="Continent")
happy_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption Code  Average Temperature  \
# ...

# %%
happy_labels = ['Very High','High', 'Moderate', 'Low','Very Low']

# %%
#Added bins to know weather happines is high or low relatively to other countries
#Do this for every column
bins = pd.cut(happy_data['Overall rank'],[0,35,70,105,140,160], labels=happy_labels)
bins.head(10)
happy_data['Happiness'] = bins

# %% [raw]
# happy_data.tail()

# %%
happy_data.plot(x = 'Overall rank', y = 'Suicide per 1000', kind = 'scatter')

# %%
happy_data.plot(x = 'Overall rank', y = 'GDP per capita', kind = 'scatter')

# %%
happy_data.plot(x = 'Overall rank', y = 'Average Temperature', kind = 'scatter')

# %%
happy_data.plot(x = 'Overall rank', y = 'Average Precipitations', kind = 'scatter')

# %%
happy_data.plot(x = 'Overall rank', y = 'Generosity', kind = 'scatter')

# %%
happy_data.plot(x = 'Overall rank', y = 'Freedom to make life choices', kind = 'scatter')

# %%
#Este es curioso porque los paises mas felices tienen más corrupcion
happy_data.plot(x = 'Overall rank', y = 'Perceptions of corruption', kind = 'scatter')

# %%
happy_data.plot(x = 'Overall rank', y = 'Social support', kind = 'scatter')

# %%
happy_data.plot(x = 'Overall rank', y = 'Healthy life expectancy', kind = 'scatter')

# %%
#We have to study typical deviation
#We can appreciate that generosity and perceptions of corruption have low std so 
#that may not determine happiness
happy_data.std()
# Out:
# Overall rank                    45.177428
# Score                            1.113120
# GDP per capita                   0.398389
# Social support                   0.299191
# Healthy life expectancy          0.242124
# Freedom to make life choices     0.143289
# Generosity                       0.095254
# Perceptions of corruption        0.094538
# Average Temperature              8.289946
# Average Precipitations          57.545244
# Suicide per 1000                 5.236834
# Avg continent happiness_x        0.000000
# Avg continent suicide_x               NaN
# Avg continent happiness_y       31.563319
# Avg continent happiness         31.563319
# Avg continent suicide_y          1.796196
# Avg continent suicide            1.796196
# dtype: float64

# %%
import smtplib

# import the corresponding modules
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

# %%
sub_happy = pd.concat([happy_data.loc[happy_data['Country or region'] == country] for country in ["Spain","United States","Australia","Burundi","China"]])
#for country in ["Spain", "USA"]:
sub_happy = sub_happy[['Country or region', 'Overall rank', 'Score', 'GDP per capita', 'Social support', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Suicide per 1000', 'Average Temperature', 'Average Precipitations']]
sub_happy
# Out:
#     Country or region  Overall rank  Score  GDP per capita  Social support  \
# 16              Spain            30  6.354           1.286           1.484
# 44      United States            19  6.892           1.433           1.457
# 41          Australia            11  7.228           1.372           1.548
# 148           Burundi           145  3.775           0.046           0.447
# 78              China            93  5.191           1.029           1.125
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 16                          0.362       0.153                      0.079
# 44                          0.454       0.280                      0.128
# 41                          0.557       0.332                      0.290
# 148                         0.220       0.176                      0.180
# 78                          0.521       0.058                      0.100
#
#      Suicide per 1000  Average Temperature  Average Precipitations
# ...

# %%
sub_happy.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Country or region</th>\n      <th>Overall rank</th>\n      <th>Score</th>\n      <th>GDP per capita</th>\n      <th>Social support</th>\n      <th>Freedom to make life choices</th>\n      <th>Generosity</th>\n      <th>Perceptions of corruption</th>\n      <th>Suicide per 1000</th>\n      <th>Average Temperature</th>\n      <th>Average Precipitations</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>16</th>\n      <td>Spain</td>\n      <td>30</td>\n      <td>6.354</td>\n      <td>1.286</td>\n      <td>1.484</td>\n      <td>0.362</td>\n      <td>0.153</td>\n      <td>0.079</td>\n      <td>6.1</td>\n      <td>14.733118</td>\n      <td>44.533546</td>\n    </tr>\n    <tr>\n      <th>44</th>\n      <td>United States</td>\n      <td>19</td>\n      <td>6.892</td>\n      <td>1.433</td>\n      <td>1.457</td>\n      <td>0.454</td>\n      <td>0.280</td>\n      <td>0.128</t
# ...

# %%
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 16             30             Spain  6.354           1.286           1.484
# 44             19     United States  6.892           1.433           1.457
# 41             11         Australia  7.228           1.372           1.548
# 148           145           Burundi  3.775           0.046           0.447
# 78             93             China  5.191           1.029           1.125
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 16                     1.062                         0.362       0.153
# 44                     0.874                         0.454       0.280
# 41                     1.036                         0.557       0.332
# 148                    0.380                         0.220       0.176
# 78                     0.893                         0.521       0.058
#
#      Perceptions of corruption Code  ...  Suicide per 1000      Continent  \
# ...

# %%
import os
from sendgrid import SendGridAPIClient
from sendgrid.helpers.mail import Mail

message = Mail(
    from_email='luciasuelves@gmail.com',
    to_emails='luciasuelves@gmail.com',
    subject='Sending with Twilio SendGrid is Fun',
    html_content = """\
<html>
  <head></head>
  <body>
    <p>Hi!<br>
       How are you?<br>
       Here is the <a href="http://www.python.org">link</a> you wanted.
    </p>
    <table border="1" class="dataframe">
        <thead>
            <tr style="text-align: center;padding:1 px">
                <th style = "padding: 1px">Country</th>
                <th style = "padding: 1px">Happy rank</th>
                <th>Happy Score</th>
                <th>GDP per capita</th>
                <th>Social support</th>
                <th>Freedom</th>
                <th>Generosity</th>\n      
                <th>Corruption</th>
                <th>Suicide ‰</th>
                <th>Avg Temperature</th>
                <th>Avg Precipitations</th>
            </tr>
        </thead>
        <tbody>
            <tr>
                <td>Spain</td>
                <td>30</td>
                <td>6.354</td>
                <td>1.286</td>
                <td>1.484</td>
                <td>0.362</td>
                <td>0.153</td>
                <td>0.079</td>
                <td>6.1</td>
                <td>14.733118</td>
                <td>44.533546</td>
            </tr>
            <tr>
                <td>United States</td>
                <td>19</td>
                <td>6.892</td>
                <td>1.433</td>
                <td>1.457</td>
                <td>0.454</td>
                <td>0.280</td>
                <td>0.128</td>
                <td>13.7</td>
                <td>7.939524</td>
                <td>56.289930</td>
            </tr>
            <tr>
                <td>Australia</td>
                <td>11</td>
                <td>7.228</td>
                <td>1.372</td>
                <td>1.548</td>
                <td>0.557</td>
                <td>0.332</td>
                <td>0.290</td>
                <td>11.7</td>
                <td>21.534817</td>
                <td>41.835380</td>
            </tr>
            <tr>
                <td>Burundi</td>
                <td>145</td>
                <td>3.775</td>
                <td>0.046</td>
                <td>0.447</td>
                <td>0.220</td>
                <td>0.176</td>
                <td>0.180</td>
                <td>15.0</td>
                <td>21.182293</td>
                <td>93.031770</td>
            </tr>
            <tr>
                <td>China</td>
                <td>93</td>
                <td>5.191</td>
                <td>1.029</td>
                <td>1.125</td>
                <td>0.521</td>
                <td>0.058</td>
                <td>0.100</td>
                <td>8.0</td>
                <td>6.582550</td>
                <td>54.482410</td>
            </tr>
        </tbody>
    </table>
  </body>
</html>
""")
try:
    sg = SendGridAPIClient("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")
    response = sg.send(message)
    print(response.status_code)
    print(response.body)
    print(response.headers)
except Exception as e:
    print(e.message)
# Out:
# 202
# b''
# Server: nginx
# Date: Mon, 03 Feb 2020 10:12:16 GMT
# Content-Length: 0
# Connection: close
# X-Message-Id: eSzJtNqyRg6o_nnN0svBjQ
# Access-Control-Allow-Origin: https://sendgrid.api-docs.io
# Access-Control-Allow-Methods: POST
# Access-Control-Allow-Headers: Authorization, Content-Type, On-behalf-of, x-sg-elas-acl
# Access-Control-Max-Age: 600
# X-No-CORS-Reason: https://sendgrid.com/docs/Classroom/Basics/API/cors.html

# %%
#Using selenium no get medals of olimpics 2016
from selenium import webdriver

class PageGetter:
    driver = False
    def __init__(self, defaultBrowser='firefox'):
        if defaultBrowser == 'firefox':
            self.driver = webdriver.Firefox()
        elif defaultBrowser == 'chrome':
            self.driver = webdriver.Chrome("/Users/luciasuelves/Downloads/chromedriver") 
        else:
            raise Exception('Not a browser')

    def getPage(self, url):
        if not self.driver:
            raise Exception("You should start a browser connection")
        self.driver.get(url)
        html = self.driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        return soup

    def close(self):
        self.driver.quit()
        
pg = PageGetter("chrome")
hdr_data = pg.getPage("https://www.bbc.com/sport/olympics/rio-2016/medals/countries")
pg.close()
#hdr_data.find_all('tr')

# %%
medals = hdr_data.find_all('table')[0].find_all('tr')[1:]
def find(medal):
    try:
        return {
            "Country": medal.find('abbr')['title'],
            "Medals": medal.select('td.medals-table__total')[0].text.strip()
        }
    except: 
        return None
table = [find(medal) for medal in medals]
table = pd.DataFrame(table)

# %%
import pandas as pd
happy_data['Olympic medals'] = 0
def medals(country):
    try: 
        medal = table.loc[table['Country'] == country]['Medals'].iloc[0]
        happy_data.loc[happy_data['Country or region'] == country, 'Olympic medals'] = medal
        return happy_data.loc[happy_data['Country or region'] == country]
    except:
        happy_data.loc[happy_data['Country or region'] == country, 'Suicide per 1000'] = None
        return None
result = [medals(country) for country in happy_data['Country or region'].tolist()]

# %%
happy_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption Code  ...  Continent  Avg continent happiness_x  \
# ...

# %%
happy_data.plot(x = 'Overall rank', y = 'Olympic medals', kind = 'scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-305-18231921e6be> in <module>
# ----> 1 happy_data.plot(x = 'Overall rank', y = 'Olympic medals', kind = 'scatter')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59                 ax = plt.gca()
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      62     plot_obj.generate()
# ...

# %%
happy_data["Olympic medals"] = pd.to_numeric(happy_data['Olympic medals'])

# %%
happy_data.plot(x = 'Overall rank', y = 'Olympic medals', kind = 'scatter')
